# %% [markdown]
# # HGI OS: AMD Developer Cloud Verification Notebook
# ## Re-Evolve on HGI · Act II Submission Lock

# %% [markdown]
# ### Phase 1: Fix Git SSL Certificate Blocker
# If you encounter `fatal: server certificate verification failed` while cloning/syncing, run this cell to bypass SSL verification for git operations in this temporary notebook environment.

# %%
# !git config --global http.sslVerify false
print("Git SSL Verification bypassed for this environment.")

# %% [markdown]
# ### Phase 2: Verify GPU Access & ROCm Support
# Run this cell to verify active AMD hardware access, HIP capabilities, and PyTorch CUDA mappings.

# %%
# !rocm-smi
# !rocminfo
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("HIP version:", getattr(torch.version, 'hip', 'N/A'))

# %% [markdown]
# ### Phase 3: Benchmark PyTorch GPU Workloads
# Run tensor operations on the GPU and print latency verification metrics.

# %%
import time
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    x = torch.randn(10000, 10000, device=device)
    start = time.time()
    y = torch.matmul(x, x)
    torch.cuda.synchronize()
    print(f"Matrix multiplication completed on GPU in {time.time() - start:.4f} seconds.")
else:
    print("GPU not available for verification.")
